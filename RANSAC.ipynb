# %%
import cv2
import numpy as np
from numpy as np
from matplotlib import pyplot as plt 
import itertools
# %matplotlib imline 
# %load_ext autoreload
# %autoreload 2
# Out:
#   File "<ipython-input-1-8c134ac6a160>", line 3
#     from numpy as np
#                 ^
# SyntaxError: invalid syntax

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt 
import itertools
# %matplotlib imline 
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8008cc72b65c> in <module>
# ----> 1 import cv2
#       2 import numpy as np
#       3 from matplotlib import pyplot as plt
#       4 import itertools
#       5 get_ipython().run_line_magic('matplotlib', 'imline ')
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt 
import itertools
# %matplotlib imline 
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-8008cc72b65c> in <module>
#       3 from matplotlib import pyplot as plt
#       4 import itertools
# ----> 5 get_ipython().run_line_magic('matplotlib', 'imline ')
#       6 get_ipython().run_line_magic('load_ext', 'autoreload')
#       7 get_ipython().run_line_magic('autoreload', '2')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# </Users/kazuki/opt/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3405         """
#    3406         from IPython.core import pylabtools as pt
# -> 3407         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3408
#    3409         if gui != 'inline':
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in find_gui_and_backend(gui, gui_select)
#     282     if gui and gui != 'auto':
#     283         # select backend based on requested gui
# --> 284         backend = backends[gui]
#     285         if gui == 'agg':
#     286             gui = None
#
# KeyError: 'imline'

# %%
#true values
_a = 0.5
_b = 0.3

# %%
#sample
points = np.array([x, a*x +_b + .1 * np.random.randn() + (np.random.randndint(100) == 0 ) * np.ramdom.rand() * 1000] for x in np.arange(0, 10, 0.01) ]))
# Out:
#   File "<ipython-input-3-5431e0c15a45>", line 2
#     points = np.array([x, a*x +_b + .1 * np.random.randn() + (np.random.randndint(100) == 0 ) * np.ramdom.rand() * 1000] for x in np.arange(0, 10, 0.01) ]))
#                                                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
#sample
points = np.array([x, a*x +_b + .1 * np.random.randn() + (np.random.randint(100) == 0 ) * np.ramdom.rand() * 1000] for x in np.arange(0, 10, 0.01) ]))
# Out:
#   File "<ipython-input-4-9a6a101ef926>", line 2
#     points = np.array([x, a*x +_b + .1 * np.random.randn() + (np.random.randint(100) == 0 ) * np.ramdom.rand() * 1000] for x in np.arange(0, 10, 0.01) ]))
#                                                                                                                                                        ^
# SyntaxError: invalid syntax

# %%
# samples
points = np.array([[x, _a * x + _b + .1 * np.random.randn() + (np.random.randint(100) == 0) * np.random.rand() * 1000] for x in np.arange(0, 10, 0.01)])

# %%
plt.plot(points[:, 0], points[:, 1])
plt.ylim(0, 10)
# Out:
# (0, 10)

# %%
data = points

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a,b

def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[;, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb

def ransac(data, 
          # parameters for RANSAC
           n = 2, #required sample num to decide parameter
           k = 1000, # max loop num
           t = 2.0 #threshold error val for inlier
           d = 800 #required inlier sample num to be correct model
          ):
    bestfit = None
    besterr = float("inf")
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2 False)]
        maybemodel = getParmWithSamples(maybeinliers)
        
        alsoinliers = []
        for p in data:
            if(p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue
                
            alsoinliers.append(p)
            
        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array(getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit
# Out:
#   File "<ipython-input-8-5be6df94573f>", line 23
#     y = data[;, 1]
#              ^
# SyntaxError: invalid syntax

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a,b

def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb

def ransac(data, 
          # parameters for RANSAC
           n = 2, #required sample num to decide parameter
           k = 1000, # max loop num
           t = 2.0 #threshold error val for inlier
           d = 800 #required inlier sample num to be correct model
          ):
    bestfit = None
    besterr = float("inf")
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2 False)]
        maybemodel = getParmWithSamples(maybeinliers)
        
        alsoinliers = []
        for p in data:
            if(p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue
                
            alsoinliers.append(p)
            
        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array(getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = thiserror
                
        iterations += 1
        return bestfit
    def leastSquare(data):
        bestfit = None
        besterr = float("inf")
        for step in [1000, 100, 10, 1, 0.1, 0.01]
           for b in np.arrange(0, 1, 0.01):
                sumerr = 0
                for p in data:
                    error = getError((a,b), p) ** 2　# **はべき乗
                    sumerr += error
                if sumerr < besterr:
                    besterr = summer
                    bestfit = (a, b)
        return bestfit
# Out:
#   File "<ipython-input-9-3a1c755474ba>", line 33
#     d = 800 #required inlier sample num to be correct model
#     ^
# SyntaxError: invalid syntax

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a,b

def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb

def ransac(data, 
          # parameters for RANSAC
           n = 2, #required sample num to decide parameter
           k = 1000, # max loop num
           t = 2.0, #threshold error val for inlier
           d = 800 #required inlier sample num to be correct model
          ):
    bestfit = None
    besterr = float("inf")
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2 False)]
        maybemodel = getParmWithSamples(maybeinliers)
        
        alsoinliers = []
        for p in data:
            if(p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue
                
            alsoinliers.append(p)
            
        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array(getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = thiserror
                
        iterations += 1
        return bestfit
    def leastSquare(data):
        bestfit = None
        besterr = float("inf")
        for step in [1000, 100, 10, 1, 0.1, 0.01]
           for b in np.arrange(0, 1, 0.01):
                sumerr = 0
                for p in data:
                    error = getError((a,b), p) ** 2　# **はべき乗
                    sumerr += error
                if sumerr < besterr:
                    besterr = summer
                    bestfit = (a, b)
        return bestfit
# Out:
#   File "<ipython-input-10-a1777bf52233>", line 39
#     maybeinliers = data[np.random.choice(len(data), 2 False)]
#                                                           ^
# SyntaxError: invalid syntax

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a,b

def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb

def ransac(data, 
          # parameters for RANSAC
           n = 2, #required sample num to decide parameter
           k = 1000, # max loop num
           t = 2.0, #threshold error val for inlier
           d = 800 #required inlier sample num to be correct model
          ):
    bestfit = None
    besterr = float("inf")
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2, False)]
        maybemodel = getParmWithSamples(maybeinliers)
        
        alsoinliers = []
        for p in data:
            if(p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue
                
            alsoinliers.append(p)
            
        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array(getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = thiserror
                
        iterations += 1
        return bestfit
    def leastSquare(data):
        bestfit = None
        besterr = float("inf")
        for step in [1000, 100, 10, 1, 0.1, 0.01]
           for b in np.arrange(0, 1, 0.01):
                sumerr = 0
                for p in data:
                    error = getError((a,b), p) ** 2　# **はべき乗
                    sumerr += error
                if sumerr < besterr:
                    besterr = summer
                    bestfit = (a, b)
        return bestfit
# Out:
#   File "<ipython-input-11-b98aa3d32588>", line 51
#     thiserror = np.array(getError(maybemodel, p) for p in data]).mean()
#                                                               ^
# SyntaxError: invalid syntax

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a,b

def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb

def ransac(data, 
          # parameters for RANSAC
           n = 2, #required sample num to decide parameter
           k = 1000, # max loop num
           t = 2.0, #threshold error val for inlier
           d = 800 #required inlier sample num to be correct model
          ):
    bestfit = None
    besterr = float("inf")
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2, False)]
        maybemodel = getParmWithSamples(maybeinliers)
        
        alsoinliers = []
        for p in data:
            if(p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue
                
            alsoinliers.append(p)
            
        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array([getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = thiserror
                
        iterations += 1
        return bestfit
    def leastSquare(data):
        bestfit = None
        besterr = float("inf")
        for step in [1000, 100, 10, 1, 0.1, 0.01]
           for b in np.arrange(0, 1, 0.01):
                sumerr = 0
                for p in data:
                    error = getError((a,b), p) ** 2　# **はべき乗
                    sumerr += error
                if sumerr < besterr:
                    besterr = summer
                    bestfit = (a, b)
        return bestfit
# Out:
#   File "<ipython-input-12-0c24ae408bad>", line 60
#     for step in [1000, 100, 10, 1, 0.1, 0.01]
#                                              ^
# SyntaxError: invalid syntax

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a,b

def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb

def ransac(data, 
          # parameters for RANSAC
           n = 2, #required sample num to decide parameter
           k = 1000, # max loop num
           t = 2.0, #threshold error val for inlier
           d = 800 #required inlier sample num to be correct model
          ):
    bestfit = None
    besterr = float("inf")
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2, False)]
        maybemodel = getParmWithSamples(maybeinliers)
        
        alsoinliers = []
        for p in data:
            if(p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue
                
            alsoinliers.append(p)
            
        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array([getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = thiserror
                
        iterations += 1
        return bestfit
    def leastSquare(data):
        bestfit = None
        besterr = float("inf")
        for step in [1000, 100, 10, 1, 0.1, 0.01]
           for a in np.arrange(0, 1, 0.01):
              for b in np.arrange(0, 1, 0.01):
                 sumerr = 0
                 for p in data:
                     error = getError((a,b), p) ** 2　# **はべき乗
                     sumerr += error
                 if sumerr < besterr:
                    besterr = summer
                    bestfit = (a, b)
        return bestfit
# Out:
#   File "<ipython-input-13-6302d89ae7ee>", line 60
#     for step in [1000, 100, 10, 1, 0.1, 0.01]
#                                              ^
# SyntaxError: invalid syntax

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a, b
    
def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b
   

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb


def ransac(data,
        # parameters for RANSAC
        n = 2, # required sample num to decide parameter
        k = 1000, # max loop num
        t = 2.0, # threshold error val for inlier
        d = 800 # requrired inlier sample num to be correnct model
    ):

    bestfit = None
    besterr = float('inf')
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2, False)]
        maybemodel = getParamWithSamples(maybeinliers)

        alsoinliers = []
        for p in data:
            if (p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue

            alsoinliers.append(p)


        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array([getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = bettermodel
                besterr = thiserror


        iterations += 1

    return bestfit

def leastSquare(data):
    bestfit = None
    besterr = float('inf')
    for step in [1000, 100, 10, 1, 0.1, 0.01]
        for a in np.arange(0, 1, 0.01):
            for b in np.arange(0, 1, 0.01):
                sumerr = 0
                for p in data:
                    error = getError((a, b), p) ** 2 # **はべき乗
                    sumerr += error
                if sumerr < besterr:
                    besterr = sumerr
                    bestfit = (a, b)
    return bestfit
# Out:
#   File "<ipython-input-14-0df4199ccf25>", line 68
#     for step in [1000, 100, 10, 1, 0.1, 0.01]
#                                              ^
# SyntaxError: invalid syntax

# %%
a,b = ransac(data)
print a,b
# Out:
#   File "<ipython-input-15-36bf545c6332>", line 2
#     print a,b
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(a,b)?

# %%
a,b = ransac(data)
print a, b
# Out:
#   File "<ipython-input-16-29d4ba5f5b3c>", line 2
#     print a, b
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(a, b)?

# %%
a,b = ransac(data)
print (a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-702b3c5d68aa> in <module>
# ----> 1 a,b = ransac(data)
#       2 print (a,b)
#
# NameError: name 'ransac' is not defined

# %%
a, b = ransac(data)
print a, b
# Out:
#   File "<ipython-input-18-5c760fa3e930>", line 2
#     print a, b
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(a, b)?

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a, b
    
def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b
   

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb


def ransac(data,
        # parameters for RANSAC
        n = 2, # required sample num to decide parameter
        k = 1000, # max loop num
        t = 2.0, # threshold error val for inlier
        d = 800 # requrired inlier sample num to be correnct model
    ):

    bestfit = None
    besterr = float('inf')
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2, False)]
        maybemodel = getParamWithSamples(maybeinliers)

        alsoinliers = []
        for p in data:
            if (p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue

            alsoinliers.append(p)


        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array([getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = bettermodel
                besterr = thiserror


        iterations += 1

    return bestfit

def leastSquare(data):
    bestfit = None
    besterr = float('inf')
    for data in [1000, 100, 10, 1, 0.1, 0.01] ##わからない
        for a in np.arange(0, 1, 0.01):
            for b in np.arange(0, 1, 0.01):
                sumerr = 0
                for p in data:
                    error = getError((a, b), p) ** 2 # **はべき乗
                    sumerr += error
                if sumerr < besterr:
                    besterr = sumerr
                    bestfit = (a, b)
    return bestfit
# Out:
#   File "<ipython-input-19-66c498681f21>", line 68
#     for data in [1000, 100, 10, 1, 0.1, 0.01]
#                                              ^
# SyntaxError: invalid syntax

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a, b
    
def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b
   

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb


def ransac(data,
        # parameters for RANSAC
        n = 2, # required sample num to decide parameter
        k = 1000, # max loop num
        t = 2.0, # threshold error val for inlier
        d = 800 # requrired inlier sample num to be correnct model
    ):

    bestfit = None
    besterr = float('inf')
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2, False)]
        maybemodel = getParamWithSamples(maybeinliers)

        alsoinliers = []
        for p in data:
            if (p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue

            alsoinliers.append(p)


        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array([getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = bettermodel
                besterr = thiserror


        iterations += 1

    return bestfit

def leastSquare(data):
    bestfit = None
    besterr = float('inf')
    for step in (1000, 100, 10, 1, 0.1, 0.01)
        for a in np.arange(0, 1, 0.01):
            for b in np.arange(0, 1, 0.01):
                sumerr = 0
                for p in data:
                    error = getError((a, b), p) ** 2
                    sumerr += error
                if sumerr < besterr:
                    besterr = sumerr
                    bestfit = (a, b)
    return bestfit
# Out:
#   File "<ipython-input-20-1fda6dc2b0fb>", line 68
#     for step in (1000, 100, 10, 1, 0.1, 0.01)
#                                              ^
# SyntaxError: invalid syntax

# %%
def getParamWithSamples(samples):
    p0 = samples[0]
    p1 = samples[1]
    dp = p1 - p0
    a = dp[1] / dp[0]
    b = p0[1] - a * p0[0]
    return a, b
    
def applyModel(model, x):
    a = model[0]
    b = model[1]
    return a * x + b
   

def getError(model, p):
    x = p[0]
    y = p[1]
    return np.abs(applyModel(model, x) - y)

def errorGrad(model, data):
    a = model[0]
    b = model[1]
    x = data[:, 0]
    y = data[:, 1]
    ga = (2 * (a * x + b - y) * x).sum()
    gb = (2 * (a * x + b - y)).sum()
    return ga, gb


def ransac(data,
        # parameters for RANSAC
        n = 2, # required sample num to decide parameter
        k = 1000, # max loop num
        t = 2.0, # threshold error val for inlier
        d = 800 # requrired inlier sample num to be correnct model
    ):

    bestfit = None
    besterr = float('inf')
    iterations = 0
    while iterations < k:
        maybeinliers = data[np.random.choice(len(data), 2, False)]
        maybemodel = getParamWithSamples(maybeinliers)

        alsoinliers = []
        for p in data:
            if (p == maybeinliers).any(): continue
            if getError(maybemodel, p) > t: continue

            alsoinliers.append(p)


        if len(alsoinliers) > d:
            bettermodel = maybemodel
            thiserror = np.array([getError(maybemodel, p) for p in data]).mean()
            if thiserror < besterr:
                bestfit = bettermodel
                besterr = thiserror


        iterations += 1

    return bestfit

def leastSquare(data):
    bestfit = None
    besterr = float('inf')
    for step in  range (1000, 100, 10, 1, 0.1, 0.01):
        for a in np.arange(0, 1, 0.01):
            for b in np.arange(0, 1, 0.01):
                sumerr = 0
                for p in data:
                    error = getError((a, b), p) ** 2
                    sumerr += error
                if sumerr < besterr:
                    besterr = sumerr
                    bestfit = (a, b)
    return bestfit

# %%
a,b = ransac(data)
print (a,b)
# Out:
# 0.5001241213182358 0.30627182257464125

# %%
plt.plot(data[:,0], data[:, 1])
l = np.array([(x, applyModel((a, b), x)) for x in data[:, 0]])
plt.plot(l[:, 0], l[:,1])
l = np.array(l[:, 0], l[:,1])
plt.plot(l[:, 0], l[:, 1])

plt.ylim(0,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-f610c82a45f3> in <module>
#       2 l = np.array([(x, applyModel((a, b), x)) for x in data[:, 0]])
#       3 plt.plot(l[:, 0], l[:,1])
# ----> 4 l = np.array(l[:, 0], l[:,1])
#       5 plt.plot(l[:, 0], l[:, 1])
#       6
#
# TypeError: data type not understood

# %%
plt.plot(data[:, 0], data[:, 1])
l = np.array([(x, applyModel((a, b), x)) for x in data[:, 0]])
plt.plot(l[:, 0], l[:, 1])
l = np.array([(x, applyModel((_a, _b), x)) for x in data[:, 0]])
plt.plot(l[:, 0], l[:, 1])

plt.ylim(0, 10)
# Out:
# (0, 10)

# %%
plt.plot(data[:,0], data[:, 1])
l = np.array([(x, applyModel((a, b), x)) for x in data[:, 0]])
plt.plot(l[:, 0], l[:,1])
l = np.array(l[:, 0], l[:,1])
plt.plot(l[:, 0], l[:, 1])

plt.ylim(0,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f610c82a45f3> in <module>
#       2 l = np.array([(x, applyModel((a, b), x)) for x in data[:, 0]])
#       3 plt.plot(l[:, 0], l[:,1])
# ----> 4 l = np.array(l[:, 0], l[:,1])
#       5 plt.plot(l[:, 0], l[:, 1])
#       6
#
# TypeError: data type not understood

# %%
plt.plot(data[:,0], data[:, 1])
l = np.array([(x, applyModel((a, b), x)) for x in data[:, 0]])
plt.plot(l[:, 0], l[:,1])
l = np.array([(x, applyModel((_a, _b), x)) for x in data[:, 0]])
plt.plot(l[:, 0], l[:, 1])

plt.ylim(0,10)
# Out:
# (0, 10)
